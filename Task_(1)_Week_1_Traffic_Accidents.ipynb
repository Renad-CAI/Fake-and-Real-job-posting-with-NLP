# %% [markdown]
# <a href="https://colab.research.google.com/github/Renad-CAI/Fake-and-Real-job-posting-with-NLP/blob/main/Task_(1)_Week_1_Traffic_Accidents.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd

df = pd.read_csv('/content/Task (1) Dataset.csv')

# %%
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %% [markdown]
# ### Handle Missing Values

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
df.sample(10)
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 2212   21:39:00    Saturday            Unknown          Male
# 9849   10:13:00    Thursday            Over 51          Male
# 3109   21:00:00      Sunday              31-50          Male
# 4737   15:40:00      Monday              18-30          Male
# 99     20:50:00      Sunday            Over 51          Male
# 2620   18:16:00   Wednesday              31-50          Male
# 11869   9:45:00      Monday            Unknown          Male
# 5917   18:48:00      Friday            Unknown          Male
# 7298   17:00:00      Friday              18-30          Male
# 3957   12:04:00      Sunday              31-50          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 2212   Junior high school                Employee         Above 10yr
# 9849    Elementary school                Employee              2-5yr
# 3109                  NaN                     NaN                NaN
# ...

# %%
df[df.isnull()]
# Out:
#       Time Day_of_week Age_band_of_driver Sex_of_driver Educational_level  \
# 0      NaN         NaN                NaN           NaN               NaN
# 1      NaN         NaN                NaN           NaN               NaN
# 2      NaN         NaN                NaN           NaN               NaN
# 3      NaN         NaN                NaN           NaN               NaN
# 4      NaN         NaN                NaN           NaN               NaN
# ...    ...         ...                ...           ...               ...
# 12311  NaN         NaN                NaN           NaN               NaN
# 12312  NaN         NaN                NaN           NaN               NaN
# 12313  NaN         NaN                NaN           NaN               NaN
# 12314  NaN         NaN                NaN           NaN               NaN
# 12315  NaN         NaN                NaN           NaN               NaN
#
#       Vehicle_driver_relation Driving_experience Type_of_vehicle  \
# ...

# %%
df.replace({'Unknown': None}, inplace=True)

# %%
df.replace({'na': None}, inplace=True)

# %%
df.replace({'None': None}, inplace=True)

# %%
df['Type_of_collision'] = df['Type_of_collision'].dropna()
df['Number_of_vehicles_involved'] = df['Number_of_vehicles_involved'].dropna()

# %%
df['Time'].replace({'00:00:00': None}, inplace=True)

# %%
df['Sex_of_driver'].fillna(method='bfill', inplace=True)

# %%
df['Casualty_severity'].fillna(0, inplace=True)

# %%
df.sample(10)
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 8113   21:33:00    Saturday           Under 18          Male
# 1921   17:38:00    Thursday              31-50          Male
# 3272   20:37:00     Tuesday               None          Male
# 6430   21:34:00      Friday              18-30          Male
# 10471  11:50:00      Monday              18-30          Male
# 213     7:00:00    Thursday              18-30          Male
# 1104   20:31:00    Saturday              18-30          Male
# 10745  19:02:00    Saturday              18-30        Female
# 7489   18:25:00   Wednesday            Over 51          Male
# 9378   17:51:00      Monday            Over 51          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 8113    Elementary school                Employee         Above 10yr
# 1921   Junior high school                Employee             5-10yr
# 3272   Junior high school                Employee              2-5yr
# ...

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver             1548
# Sex_of_driver                     0
# Educational_level               841
# Vehicle_driver_relation         593
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        6811
# Defect_of_vehicle              4427
# Area_accident_occured           261
# Lanes_or_Medians                442
# Road_allignment                 142
# Types_of_Junction              1078
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions              292
# Type_of_collision               169
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                396
# Casualty_class                 4443
# Sex_of_casualty                4443
# Age_band_of_casualty           4443
# ...

# %%
df.dropna(inplace=True)

# %%
df.sample(10)
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 391    16:51:00   Wednesday              31-50          Male
# 2421   18:09:00      Monday              18-30          Male
# 5037    8:27:00    Thursday              31-50          Male
# 10499  15:10:00   Wednesday              31-50          Male
# 5762   13:00:00    Thursday              18-30          Male
# 10327   7:50:00    Thursday              18-30          Male
# 4152    8:40:00    Thursday              18-30          Male
# 8124   19:20:00      Monday              18-30          Male
# 2850    8:05:00    Thursday              18-30          Male
# 6187   18:00:00      Monday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 391           High school                Employee          Below 1yr
# 2421          High school                Employee          Below 1yr
# 5037   Junior high school                Employee         Above 10yr
# ...

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
# There is no inconsistent data

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 946 entries, 8 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         946 non-null    object
#  1   Day_of_week                  946 non-null    object
#  2   Age_band_of_driver           946 non-null    object
#  3   Sex_of_driver                946 non-null    object
#  4   Educational_level            946 non-null    object
#  5   Vehicle_driver_relation      946 non-null    object
#  6   Driving_experience           946 non-null    object
#  7   Type_of_vehicle              946 non-null    object
#  8   Owner_of_vehicle             946 non-null    object
#  9   Service_year_of_vehicle      946 non-null    object
#  10  Defect_of_vehicle            946 non-null    object
#  11  Area_accident_occured        946 non-null    object
#  12  Lanes_or_Medians             946 non-null    object
# ...

# %%
df['Time'] = pd.to_datetime(df['Time'])
# Out:
# <ipython-input-194-1bfd8981fe14>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Time'] = pd.to_datetime(df['Time'])

# %%
df['Sex_of_driver']= df['Sex_of_driver'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 946 entries, 8 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         946 non-null    datetime64[ns]
#  1   Day_of_week                  946 non-null    object
#  2   Age_band_of_driver           946 non-null    object
#  3   Sex_of_driver                946 non-null    category
#  4   Educational_level            946 non-null    object
#  5   Vehicle_driver_relation      946 non-null    object
#  6   Driving_experience           946 non-null    object
#  7   Type_of_vehicle              946 non-null    object
#  8   Owner_of_vehicle             946 non-null    object
#  9   Service_year_of_vehicle      946 non-null    object
#  10  Defect_of_vehicle            946 non-null    object
#  11  Area_accident_occured        946 non-null    object
# ...

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.describe()
# Out:
#                                 Time  Number_of_vehicles_involved  \
# count                            946                   946.000000
# mean   2024-07-25 14:06:44.460887808                     1.986258
# min              2024-07-25 00:06:00                     1.000000
# 25%              2024-07-25 09:41:15                     2.000000
# 50%              2024-07-25 14:58:00                     2.000000
# 75%              2024-07-25 18:20:00                     2.000000
# max              2024-07-25 23:56:00                     4.000000
# std                              NaN                     0.580842
#
#        Number_of_casualties
# count            946.000000
# mean               1.545455
# min                1.000000
# 25%                1.000000
# 50%                1.000000
# 75%                2.000000
# max                7.000000
# std                1.016554

# %%
df['Number_of_vehicles_involved'].mean()
# Out:
# 1.9862579281183932

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
numerical_columns = ['Number_of_vehicles_involved', 'Number_of_casualties', 'Casualty_severity']

correlation_matrix = df[numerical_columns].corr()
correlation_matrix
# Out:
#                              Number_of_vehicles_involved  \
# Number_of_vehicles_involved                     1.000000
# Number_of_casualties                            0.260028
# Casualty_severity                               0.049993
#
#                              Number_of_casualties  Casualty_severity
# Number_of_vehicles_involved              0.260028           0.049993
# Number_of_casualties                     1.000000          -0.010207
# Casualty_severity                       -0.010207           1.000000

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
df.loc[:, ['Type_of_collision', 'Number_of_vehicles_involved']]
# Out:
#                              Type_of_collision  Number_of_vehicles_involved
# 8      Collision with roadside-parked vehicles                            2
# 9      Collision with roadside-parked vehicles                            2
# 14                      Collision with animals                            2
# 19                      Collision with animals                            2
# 21                      Collision with animals                            1
# ...                                        ...                          ...
# 12296           Vehicle with vehicle collision                            2
# 12298           Vehicle with vehicle collision                            2
# 12300           Vehicle with vehicle collision                            1
# 12313           Vehicle with vehicle collision                            1
# 12315           Vehicle with vehicle collision                            2
#
# [946 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

collision = df['Type_of_collision'].value_counts()

collision.plot(kind='barh')
plt.title('Number of collision over collision types')
plt.xlabel('Number of collision')
plt.ylabel('Type of collision')

plt.show()

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
import seaborn as sns

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap Between Variables')
plt.show()

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
import matplotlib.pyplot as plt

Area_accident_occured_counts = df['Area_accident_occured'].value_counts()

Area_accident_occured_counts.plot(kind='barh')
plt.title('Number of Accident vs Area')
plt.xlabel('Number of Accident')
plt.ylabel('Area')

plt.show()

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
import matplotlib.pyplot as plt

gender_counts = df['Sex_of_driver'].value_counts()

plt.figure(figsize=(8, 8))
gender_counts.plot(kind='pie')
plt.title('Driver Gender Distribution')
plt.show()

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %%
# The insight from Driver Gender Distribution that describe how many Male and Famaels and it seems males are more drivers than females
# The realationship between Area accident occured and the the Number of Accident
# In Number of collision over collision types bar chart, we can see what is collision types that happen always and frequently
